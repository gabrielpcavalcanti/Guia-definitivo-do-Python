# %% [markdown]
# # Aula 1 - Console
#
# O objeto Console é o coração da Rich. É através dele que você imprime coisas bonitas no terminal.
#
# O Console substitui o print() tradicional e adiciona superpoderes de formatação.
#
# Ele é uma classe, como qualquer outro elemento no Python. Portanto ela possui muitos métodos interessantes que veremos aqui.

# %% [markdown]
# ### Importar e Inistânciar a classe
#
# Para cada um das features do rich, é preciso importar um módulo diferente e sua classe correspondente. O padrão sempre será:
#
# ```Python
# from rich.modulo import classe.
# ```
#
# Para instânciar e criar um objeto, fazemos como qualquer outro objeto no Pyhton.
#
# Veja abaixo:

# %%
from rich.console import Console

console = Console()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from rich.console import Console
#       3 console = Console()
#
# ModuleNotFoundError: No module named 'rich'

# %% [markdown]
# ### 1 -  print( ) aprimorado
#
# O método print da classe Console possui diversas configurações legais que podem ser utilizados.

# %% [markdown]
# #### Utilizar style para Strings
#
# Existem diversas configurações de estilos para as Strings. Ele aceita as cores:
#
# black, red, green, yellow, blue, magenta, cyan, white
#
# Ele aceita também o bright_cor e dark_cor.
#
# Escalada de cinza: grey0   até   grey100
#
# Ele aceita também RGB E HEX.
#
# Pode também tem cores de fundo: Basta utilizar o on.
#
# Aceita esses estilos: bold, dim, italic, underline, blink, reverse, strike
#
# Texto estático (hardcoded) é melhor utilizar o markup: console.print("[bold cyan]=== MENU ===[/]") Sempre é [estilo]texto[/]
#
# ## Emojis
#
# Status / UI
# :check_mark:
# :cross_mark:
# :warning:
# :information_source:
# :question:
#
# Sistema / Código
# :gear:
# :hammer:
# :wrench:
# :computer:
# :floppy_disk:
#
# Progresso
# :rocket:
# :hourglass:
# :fire:
# :zap:
#
# Usuário
# :bust_in_silhouette:
# :busts_in_silhouette:
# :lock:
# :unlock:
#
# Pode usar emojis diretemante: 🔥
# Unicode: ✔  ✖  ⚠  ➜  ➤  ★  ☆  ●  ○  ▸  ▾

# %%
console.print(":rocket:", style="green")
