# %% [markdown]
# ## Exercícios — Rich Console parte 01

# %% [markdown]
# ### Exercício 1 — Substituindo o print()
#
# Crie um Console e imprima:
#
#  - Seu nome em bold
#
#  - Uma mensagem de sucesso em verde e itálico
#
#  - Uma mensagem de erro em vermelho e underline
#
# Use markup ([bold], [red], etc.) ou Style.

# %%
from rich.console import Console

console = Console()

console.print("Gabriel Purificação Cavalcanti", style="bold")
console.print("O processo foi feito com sucesso", style="italic green")
console.print("[underline red]O processo foi feito com erro[/]")
# Out:
# Gabriel Purificação Cavalcanti
# O processo foi feito com sucesso
# O processo foi feito com erro

# %% [markdown]
# ### Exercício 2 — Cores claras e fundo
#
# Imprima "AVISO" em: preto com fundo amarelo claro e  Imprima "INFO" em branco  e fundo azul.

# %%
from rich.console import Console

console = Console()

console.print("AVISO", style="black on bright_yellow")
console.print("INFO", style="white on blue")
# Out:
# AVISO
# INFO

# %% [markdown]
# ### Exercício 3 — Múltiplos textos no mesmo print
#
# Use um único console.print() para mostrar: "Status:" em cyan e "OK" em verde e negrito.

# %%
from rich.console import Console

console = Console()

console.print("[cyan]Status[/]", "[bold green]OK[/]")
# Out:
# Status OK

# %% [markdown]
# ### Exercício 4 — Emojis e Unicode
#
# Imprima um emoji de sucesso em verde e um emoji de erro em vermelho. Depois coloque 4 emojis da sua escolha na mesma linha.

# %%
from rich.console import Console

console = Console()

console.print("✔ Sucesso", style="green")
console.print("✖ Erro", style="red")

console.print(":rocket:", ":hourglass:", ":wrench:", ":computer:", sep=" ")
# Out:
# ✔ Sucesso
# ✖ Erro
# 🚀 ⌛ 🔧 💻

# %% [markdown]
# Exercicio 5 - "Desafio"
#
# Crie uma saída de terminal parecida com:
#
# === SISTEMA ===
#
# ✔ Iniciado
#
# ⚠ Atenção
#
# ✖ Falha
#
# O "iniciado" em verde, o "atenção" em amarelo e o "falha" em vermelho.

# %%
from rich.console import Console

console = Console()

console.print("[bright_black]=== SISTEMA ===[/]")
console.print("✔ Iniciado", style="green")
console.print("⚠ Atenção", style="yellow")
console.print("✖ Falha", style="red")
# Out:
# === SISTEMA ===
# ✔ Iniciado
# ⚠ Atenção
# ✖ Falha

# %% [markdown]
# ---
