# %% [markdown]
# # Gráficos

# %%
from sympy import *

init_printing(pretty_print=True)

x, y, z = symbols('x y z')

# %%
plot(x**3)

# %%
plot(x**2, 5*sin(x),(x,-2,2), title = "teste", xlabel= "eixo x", ylabel= "eixo y", legend=True)
